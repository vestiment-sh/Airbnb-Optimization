# %%
# import module
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 50)
# %matplotlib inline

# %%
# import dataset
df_merge = pd.read_csv('df_merge.csv')

# %%
# Count of listing each borough
df_merge.groupby('borough')['id'].count()
# Out:
# borough
# Bronx             378
# Brooklyn         7002
# Manhattan        7371
# Queens           1890
# Staten Island     147
# Name: id, dtype: int64

# %%
# Average for each Borough 
df_merge.groupby('borough').mean()
# Out:
#                  Unnamed: 0            id  host_response_rate  \
# borough
# Bronx           6539.013228  1.250576e+07           96.140212
# Brooklyn        5251.562696  1.061105e+07           95.539703
# Manhattan      11725.382445  1.066643e+07           95.077737
# Queens          7424.256085  1.229193e+07           96.656085
# Staten Island   8212.591837  1.128951e+07           98.299320
#
#                host_is_superhost  host_total_listings_count  \
# borough
# Bronx                   0.285714                   3.029101
# Brooklyn                0.223650                   2.289489
# Manhattan               0.172975                   2.808845
# Queens                  0.219577                   2.822222
# Staten Island           0.258503                   2.884354
#
#                host_has_profile_pic  host_identity_verified       zipcode  \
# borough
# Bronx                      0.997354                0.645503  10461.989418
# Brooklyn                   0.999429                0.763353  11219.216367
# Manhattan                  0.998508                0.718084  10023.696920
# Queens                     0.999471                0.636508  11294.544974
# Staten Island              0.993197                0.591837  10304.421769
#
#                accommodates  bathrooms  bedrooms      beds       price  \
# borough
# Bronx              2.783069   1.146825  1.111111  1.605820   72.314815
# Brooklyn           3.065838   1.185161  1.273922  1.714796  119.273065
# Manhattan          3.115452   1.119997  1.170126  1.683082  183.711844
# Queens             3.032804   1.119048  1.215344  1.732275   96.805291
# Staten Island      3.666667   1.261905  1.401361  2.170068   94.013605
#
#                minimum_nights  maximum_nights  number_of_reviews  \
# borough
# Bronx                2.931217      555.076720          26.732804
# Brooklyn             3.622251    71054.528278          30.869751
# Manhattan            3.762176     1017.428164          33.233754
# Queens               3.146561    81571.632275          33.667725
# Staten Island        3.006803      495.455782          31.523810
#
#                review_scores_rating  review_scores_accuracy  \
# borough
# Bronx                     93.285714                9.568783
# Brooklyn                  94.270066                9.655813
# Manhattan                 93.631800                9.561661
# Queens                    93.956085                9.626984
# Staten Island             93.639456                9.530612
#
#                review_scores_cleanliness  review_scores_checkin  \
# borough
# Bronx                           9.402116               9.764550
# Brooklyn                        9.372179               9.798343
# Manhattan                       9.300909               9.734636
# Queens                          9.435979               9.793122
# Staten Island                   9.435374               9.748299
#
#                review_scores_communication  review_scores_location  \
# borough
# Bronx                             9.788360                8.910053
# Brooklyn                          9.801771                9.312911
# Manhattan                         9.764889                9.602768
# Queens                            9.780423                9.351323
# Staten Island                     9.741497                9.163265
#
#                review_scores_value  Price_daily           zip    population  \
# borough
# Bronx                     9.439153    41.607092  10461.989418  63522.685185
# Brooklyn                  9.470580    62.099377  11219.216367  66852.986290
# Manhattan                 9.346900    97.445129  10023.696920  48008.215439
# Queens                    9.482540    57.098696  11294.544974  51901.347090
# Staten Island             9.462585    51.345670  10304.421769  42712.163265
#
#                     density
# borough
# Bronx          48784.976190
# Brooklyn       47061.188660
# Manhattan      83032.811287
# Queens         36459.669841
# Staten Island  10246.734694

# %%
# Count of Listing for each Neighborhood
pd.DataFrame(df_merge.groupby(['borough','neighborhood'])['id'].count())
# Out:
#                                                id
# borough       neighborhood
# Bronx         Bronx Park and Fordham           51
#               Central Bronx                    38
#               High Bridge and Morrisania       66
#               Hunts Point and Mott Haven       43
#               Kingsbridge and Riverdale        39
#               Northeast Bronx                  65
#               Southeast Bronx                  76
# Brooklyn      Borough Park                    180
#               Bushwick and Williamsburg      1707
#               Canarsie and Flatlands           69
#               Central Brooklyn               1525
#               East New York and New Lots      230
#               Flatbush                        656
#               Greenpoint                     1188
#               Northwest Brooklyn             1141
#               Southern Brooklyn               104
#               Southwest Brooklyn               87
#               Sunset Park                     115
# Manhattan     Central Harlem                  831
#               Chelsea and Clinton            1302
#               East Harlem                     446
#               Gramercy Park and Murray Hill   570
#               Greenwich Village and Soho      755
#               Inwood and Washington Heights   768
#               Lower East Side                1295
#               Lower Manhattan                 148
#               Tribeca                           2
#               Upper East Side                 608
#               Upper West Side                 641
#               West Side                         5
# Queens        Central Queens                   28
#               Jamaica                         127
#               Long Island City                  5
#               North Queens                    161
#               Northeast Queens                 26
#               Northwest Queens                702
#               Rockaways                        93
#               Southeast Queens                 57
#               Southwest Queens                 92
#               West Central Queens             238
#               West Queens                     361
# Staten Island Mid-Island                        7
#               Port Richmond                    11
#               South Shore                      22
#               Stapleton and St. George        107

# %%
# Price Correlation 
pd.DataFrame(df_merge.corr()['Price_daily']).sort_values('Price_daily')
# Out:
#                              Price_daily
# zip                            -0.139276
# zipcode                        -0.139276
# minimum_nights                 -0.131083
# population                     -0.094293
# review_scores_communication    -0.062375
# review_scores_checkin          -0.059721
# review_scores_value            -0.039742
# review_scores_accuracy         -0.037056
# host_response_rate             -0.018621
# review_scores_rating           -0.012882
# host_identity_verified         -0.009257
# maximum_nights                 -0.001603
# host_total_listings_count      -0.001420
# review_scores_cleanliness       0.003620
# host_has_profile_pic            0.004368
# host_is_superhost               0.013913
# id                              0.016152
# number_of_reviews               0.029765
# density                         0.065438
# Unnamed: 0                      0.085578
# review_scores_location          0.096291
# bathrooms                       0.264883
# bedrooms                        0.291552
# beds                            0.300101
# accommodates                    0.393004
# price                           0.757836
# Price_daily                     1.000000

# %%
# To10
pd.DataFrame(df_merge.corr()['Price_daily']).sort_values('Price_daily')[pd.DataFrame(df_merge.corr()['Price_daily']).sort_values('Price_daily', ascending=False)['Price_daily']>0]
# Out:
# /Users/soichiro/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                            Price_daily
# review_scores_cleanliness     0.003620
# host_has_profile_pic          0.004368
# host_is_superhost             0.013913
# id                            0.016152
# number_of_reviews             0.029765
# density                       0.065438
# Unnamed: 0                    0.085578
# review_scores_location        0.096291
# bathrooms                     0.264883
# bedrooms                      0.291552
# beds                          0.300101
# accommodates                  0.393004
# price                         0.757836
# Price_daily                   1.000000

# %%
# Review_scores_rating Correlation 
pd.DataFrame(df_merge.corr()['review_scores_rating']).sort_values('review_scores_rating')
# Out:
#                              review_scores_rating
# number_of_reviews                       -0.062120
# accommodates                            -0.061649
# beds                                    -0.056025
# bedrooms                                -0.033462
# density                                 -0.027377
# bathrooms                               -0.020377
# host_total_listings_count               -0.020153
# population                              -0.014811
# Unnamed: 0                              -0.013673
# Price_daily                             -0.012882
# maximum_nights                          -0.004560
# minimum_nights                          -0.001814
# price                                    0.006919
# host_has_profile_pic                     0.027620
# host_identity_verified                   0.040255
# zipcode                                  0.041937
# zip                                      0.041937
# host_response_rate                       0.075396
# id                                       0.077462
# host_is_superhost                        0.218576
# review_scores_location                   0.436763
# review_scores_checkin                    0.571192
# review_scores_communication              0.614476
# review_scores_cleanliness                0.692160
# review_scores_accuracy                   0.725072
# review_scores_value                      0.730322
# review_scores_rating                     1.000000

# %%
# host_is_superhost Correlation 
pd.DataFrame(df_merge.corr()['host_is_superhost']).sort_values('host_is_superhost')
# Out:
#                              host_is_superhost
# id                                   -0.103487
# density                              -0.051090
# Unnamed: 0                           -0.026835
# minimum_nights                       -0.018970
# bathrooms                            -0.015232
# host_total_listings_count            -0.005575
# maximum_nights                       -0.004778
# bedrooms                              0.003846
# population                            0.006504
# price                                 0.012732
# Price_daily                           0.013913
# host_has_profile_pic                  0.016516
# accommodates                          0.017006
# beds                                  0.017851
# zipcode                               0.058975
# zip                                   0.058975
# review_scores_location                0.081287
# host_identity_verified                0.116628
# host_response_rate                    0.127559
# review_scores_communication           0.152978
# review_scores_checkin                 0.155534
# review_scores_accuracy                0.201471
# review_scores_value                   0.202488
# review_scores_rating                  0.218576
# number_of_reviews                     0.223940
# review_scores_cleanliness             0.230050
# host_is_superhost                     1.000000

# %%
# All Corr
df_merge.corr()
# Out:
#                              Unnamed: 0        id  host_response_rate  \
# Unnamed: 0                     1.000000  0.009410           -0.009328
# id                             0.009410  1.000000            0.056598
# host_response_rate            -0.009328  0.056598            1.000000
# host_is_superhost             -0.026835 -0.103487            0.127559
# host_total_listings_count      0.010309  0.004564            0.014255
# host_has_profile_pic          -0.009304  0.004271            0.016102
# host_identity_verified        -0.039762 -0.261496            0.013797
# zipcode                       -0.573275  0.027310            0.025844
# accommodates                   0.002821  0.011325            0.043687
# bathrooms                     -0.066716  0.012457            0.019046
# bedrooms                      -0.041017 -0.014068            0.030713
# beds                           0.001283  0.004864            0.049738
# price                          0.102480 -0.030899           -0.029584
# minimum_nights                 0.005979 -0.066589           -0.029910
# maximum_nights                -0.009415 -0.003907            0.001715
# number_of_reviews             -0.006515 -0.445613            0.101149
# review_scores_rating          -0.013673  0.077462            0.075396
# review_scores_accuracy        -0.029005  0.062258            0.066046
# review_scores_cleanliness     -0.001361  0.089938            0.097697
# review_scores_checkin         -0.025436 -0.001765            0.067255
# review_scores_communication   -0.004767 -0.020179            0.077800
# review_scores_location         0.165979  0.072076            0.015158
# review_scores_value           -0.026505  0.116462            0.082267
# Price_daily                    0.085578  0.016152           -0.018621
# zip                           -0.573275  0.027310            0.025844
# population                    -0.245379 -0.009727            0.003188
# density                        0.360087 -0.037084           -0.018419
#
#                              host_is_superhost  host_total_listings_count  \
# Unnamed: 0                           -0.026835                   0.010309
# id                                   -0.103487                   0.004564
# host_response_rate                    0.127559                   0.014255
# host_is_superhost                     1.000000                  -0.005575
# host_total_listings_count            -0.005575                   1.000000
# host_has_profile_pic                  0.016516                   0.002627
# host_identity_verified                0.116628                   0.018131
# zipcode                               0.058975                  -0.010395
# accommodates                          0.017006                   0.007521
# bathrooms                            -0.015232                   0.030890
# bedrooms                              0.003846                   0.005754
# beds                                  0.017851                   0.001149
# price                                 0.012732                   0.013197
# minimum_nights                       -0.018970                   0.064319
# maximum_nights                       -0.004778                  -0.000334
# number_of_reviews                     0.223940                  -0.012759
# review_scores_rating                  0.218576                  -0.020153
# review_scores_accuracy                0.201471                  -0.031477
# review_scores_cleanliness             0.230050                   0.001528
# review_scores_checkin                 0.155534                  -0.011190
# review_scores_communication           0.152978                  -0.052237
# review_scores_location                0.081287                  -0.036153
# review_scores_value                   0.202488                  -0.039981
# Price_daily                           0.013913                  -0.001420
# zip                                   0.058975                  -0.010395
# population                            0.006504                  -0.027246
# density                              -0.051090                  -0.014722
#
#                              host_has_profile_pic  host_identity_verified  \
# Unnamed: 0                              -0.009304               -0.039762
# id                                       0.004271               -0.261496
# host_response_rate                       0.016102                0.013797
# host_is_superhost                        0.016516                0.116628
# host_total_listings_count                0.002627                0.018131
# host_has_profile_pic                     1.000000                0.045048
# host_identity_verified                   0.045048                1.000000
# zipcode                                  0.015033                0.016181
# accommodates                             0.001329               -0.007436
# bathrooms                                0.004738               -0.020330
# bedrooms                                 0.013858               -0.007031
# beds                                    -0.001922               -0.012861
# price                                   -0.005720                0.005835
# minimum_nights                          -0.006119                0.020671
# maximum_nights                           0.000318                0.000867
# number_of_reviews                       -0.000469                0.131660
# review_scores_rating                     0.027620                0.040255
# review_scores_accuracy                   0.023306                0.046457
# review_scores_cleanliness                0.008989                0.012810
# review_scores_checkin                    0.034829                0.050373
# review_scores_communication              0.038909                0.063331
# review_scores_location                   0.014294                0.006829
# review_scores_value                      0.020838                0.023738
# Price_daily                              0.004368               -0.009257
# zip                                      0.015033                0.016181
# population                               0.004391                0.017537
# density                                  0.004146               -0.002013
#
#                               zipcode  accommodates  bathrooms  bedrooms  \
# Unnamed: 0                  -0.573275      0.002821  -0.066716 -0.041017
# id                           0.027310      0.011325   0.012457 -0.014068
# host_response_rate           0.025844      0.043687   0.019046  0.030713
# host_is_superhost            0.058975      0.017006  -0.015232  0.003846
# host_total_listings_count   -0.010395      0.007521   0.030890  0.005754
# host_has_profile_pic         0.015033      0.001329   0.004738  0.013858
# host_identity_verified       0.016181     -0.007436  -0.020330 -0.007031
# zipcode                      1.000000     -0.015006   0.053743  0.055956
# accommodates                -0.015006      1.000000   0.379214  0.697686
# bathrooms                    0.053743      0.379214   1.000000  0.440378
# bedrooms                     0.055956      0.697686   0.440378  1.000000
# beds                         0.012683      0.833063   0.432490  0.707796
# price                       -0.181467      0.433395   0.305614  0.367824
# minimum_nights              -0.014731     -0.056466   0.000638 -0.017461
# maximum_nights               0.008144     -0.003980  -0.003119 -0.002687
# number_of_reviews           -0.021943      0.068949  -0.021042  0.000220
# review_scores_rating         0.041937     -0.061649  -0.020377 -0.033462
# review_scores_accuracy       0.060993     -0.068738  -0.028750 -0.057321
# review_scores_cleanliness    0.048335     -0.004958  -0.015471 -0.014183
# review_scores_checkin        0.053122     -0.045771  -0.034443 -0.022821
# review_scores_communication  0.027851     -0.069036  -0.066670 -0.050480
# review_scores_location      -0.182880     -0.025669  -0.033054 -0.031997
# review_scores_value          0.081913     -0.066751  -0.019917 -0.030810
# Price_daily                 -0.139276      0.393004   0.264883  0.291552
# zip                          1.000000     -0.015006   0.053743  0.055956
# population                   0.330516     -0.047266   0.021594  0.008278
# density                     -0.634000     -0.026631  -0.037161 -0.062135
#
#                                  beds     price  minimum_nights  \
# Unnamed: 0                   0.001283  0.102480        0.005979
# id                           0.004864 -0.030899       -0.066589
# host_response_rate           0.049738 -0.029584       -0.029910
# host_is_superhost            0.017851  0.012732       -0.018970
# host_total_listings_count    0.001149  0.013197        0.064319
# host_has_profile_pic        -0.001922 -0.005720       -0.006119
# host_identity_verified      -0.012861  0.005835        0.020671
# zipcode                      0.012683 -0.181467       -0.014731
# accommodates                 0.833063  0.433395       -0.056466
# bathrooms                    0.432490  0.305614        0.000638
# bedrooms                     0.707796  0.367824       -0.017461
# beds                         1.000000  0.360370       -0.031452
# price                        0.360370  1.000000        0.025508
# minimum_nights              -0.031452  0.025508        1.000000
# maximum_nights              -0.003611 -0.003961       -0.002286
# number_of_reviews            0.052212 -0.023450       -0.089136
# review_scores_rating        -0.056025  0.006919       -0.001814
# review_scores_accuracy      -0.071856 -0.035950       -0.008796
# review_scores_cleanliness   -0.006166  0.010598       -0.037358
# review_scores_checkin       -0.038637 -0.046115       -0.011425
# review_scores_communication -0.059066 -0.051299       -0.019712
# review_scores_location      -0.033596  0.121186       -0.000448
# review_scores_value         -0.057060 -0.038877       -0.021104
# Price_daily                  0.300101  0.757836       -0.131083
# zip                          0.012683 -0.181467       -0.014731
# population                  -0.031875 -0.122190       -0.017043
# density                     -0.040826  0.089869       -0.001498
#
#                              maximum_nights  number_of_reviews  \
# Unnamed: 0                        -0.009415          -0.006515
# id                                -0.003907          -0.445613
# host_response_rate                 0.001715           0.101149
# host_is_superhost                 -0.004778           0.223940
# host_total_listings_count         -0.000334          -0.012759
# host_has_profile_pic               0.000318          -0.000469
# host_identity_verified             0.000867           0.131660
# zipcode                            0.008144          -0.021943
# accommodates                      -0.003980           0.068949
# bathrooms                         -0.003119          -0.021042
# bedrooms                          -0.002687           0.000220
# beds                              -0.003611           0.052212
# price                             -0.003961          -0.023450
# minimum_nights                    -0.002286          -0.089136
# maximum_nights                     1.000000          -0.000992
# number_of_reviews                 -0.000992           1.000000
# review_scores_rating              -0.004560          -0.062120
# review_scores_accuracy            -0.005145          -0.020660
# review_scores_cleanliness         -0.009746          -0.007008
# review_scores_checkin             -0.009078           0.029992
# review_scores_communication        0.003703           0.022508
# review_scores_location            -0.005618          -0.066468
# review_scores_value               -0.002382          -0.048176
# Price_daily                       -0.001603           0.029765
# zip                                0.008144          -0.021943
# population                         0.008855          -0.005017
# density                           -0.006191           0.004874
#
#                              review_scores_rating  review_scores_accuracy  \
# Unnamed: 0                              -0.013673               -0.029005
# id                                       0.077462                0.062258
# host_response_rate                       0.075396                0.066046
# host_is_superhost                        0.218576                0.201471
# host_total_listings_count               -0.020153               -0.031477
# host_has_profile_pic                     0.027620                0.023306
# host_identity_verified                   0.040255                0.046457
# zipcode                                  0.041937                0.060993
# accommodates                            -0.061649               -0.068738
# bathrooms                               -0.020377               -0.028750
# bedrooms                                -0.033462               -0.057321
# beds                                    -0.056025               -0.071856
# price                                    0.006919               -0.035950
# minimum_nights                          -0.001814               -0.008796
# maximum_nights                          -0.004560               -0.005145
# number_of_reviews                       -0.062120               -0.020660
# review_scores_rating                     1.000000                0.725072
# review_scores_accuracy                   0.725072                1.000000
# review_scores_cleanliness                0.692160                0.577087
# review_scores_checkin                    0.571192                0.527982
# review_scores_communication              0.614476                0.553442
# review_scores_location                   0.436763                0.337560
# review_scores_value                      0.730322                0.641034
# Price_daily                             -0.012882               -0.037056
# zip                                      0.041937                0.060993
# population                              -0.014811                0.013531
# density                                 -0.027377               -0.023356
#
#                              review_scores_cleanliness  review_scores_checkin  \
# Unnamed: 0                                   -0.001361              -0.025436
# id                                            0.089938              -0.001765
# host_response_rate                            0.097697               0.067255
# host_is_superhost                             0.230050               0.155534
# host_total_listings_count                     0.001528              -0.011190
# host_has_profile_pic                          0.008989               0.034829
# host_identity_verified                        0.012810               0.050373
# zipcode                                       0.048335               0.053122
# accommodates                                 -0.004958              -0.045771
# bathrooms                                    -0.015471              -0.034443
# bedrooms                                     -0.014183              -0.022821
# beds                                         -0.006166              -0.038637
# price                                         0.010598              -0.046115
# minimum_nights                               -0.037358              -0.011425
# maximum_nights                               -0.009746              -0.009078
# number_of_reviews                            -0.007008               0.029992
# review_scores_rating                          0.692160               0.571192
# review_scores_accuracy                        0.577087               0.527982
# review_scores_cleanliness                     1.000000               0.440638
# review_scores_checkin                         0.440638               1.000000
# review_scores_communication                   0.430904               0.648214
# review_scores_location                        0.286222               0.304167
# review_scores_value                           0.587991               0.502197
# Price_daily                                   0.003620              -0.059721
# zip                                           0.048335               0.053122
# population                                   -0.025411               0.005734
# density                                      -0.050662              -0.024750
#
#                              review_scores_communication  \
# Unnamed: 0                                     -0.004767
# id                                             -0.020179
# host_response_rate                              0.077800
# host_is_superhost                               0.152978
# host_total_listings_count                      -0.052237
# host_has_profile_pic                            0.038909
# host_identity_verified                          0.063331
# zipcode                                         0.027851
# accommodates                                   -0.069036
# bathrooms                                      -0.066670
# bedrooms                                       -0.050480
# beds                                           -0.059066
# price                                          -0.051299
# minimum_nights                                 -0.019712
# maximum_nights                                  0.003703
# number_of_reviews                               0.022508
# review_scores_rating                            0.614476
# review_scores_accuracy                          0.553442
# review_scores_cleanliness                       0.430904
# review_scores_checkin                           0.648214
# review_scores_communication                     1.000000
# review_scores_location                          0.318908
# review_scores_value                             0.519517
# Price_daily                                    -0.062375
# zip                                             0.027851
# population                                      0.002818
# density                                         0.003124
#
#                              review_scores_location  review_scores_value  \
# Unnamed: 0                                 0.165979            -0.026505
# id                                         0.072076             0.116462
# host_response_rate                         0.015158             0.082267
# host_is_superhost                          0.081287             0.202488
# host_total_listings_count                 -0.036153            -0.039981
# host_has_profile_pic                       0.014294             0.020838
# host_identity_verified                     0.006829             0.023738
# zipcode                                   -0.182880             0.081913
# accommodates                              -0.025669            -0.066751
# bathrooms                                 -0.033054            -0.019917
# bedrooms                                  -0.031997            -0.030810
# beds                                      -0.033596            -0.057060
# price                                      0.121186            -0.038877
# minimum_nights                            -0.000448            -0.021104
# maximum_nights                            -0.005618            -0.002382
# number_of_reviews                         -0.066468            -0.048176
# review_scores_rating                       0.436763             0.730322
# review_scores_accuracy                     0.337560             0.641034
# review_scores_cleanliness                  0.286222             0.587991
# review_scores_checkin                      0.304167             0.502197
# review_scores_communication                0.318908             0.519517
# review_scores_location                     1.000000             0.410772
# review_scores_value                        0.410772             1.000000
# Price_daily                                0.096291            -0.039742
# zip                                       -0.182880             0.081913
# population                                -0.182883             0.004245
# density                                    0.093958            -0.049165
#
#                              Price_daily       zip  population   density
# Unnamed: 0                      0.085578 -0.573275   -0.245379  0.360087
# id                              0.016152  0.027310   -0.009727 -0.037084
# host_response_rate             -0.018621  0.025844    0.003188 -0.018419
# host_is_superhost               0.013913  0.058975    0.006504 -0.051090
# host_total_listings_count      -0.001420 -0.010395   -0.027246 -0.014722
# host_has_profile_pic            0.004368  0.015033    0.004391  0.004146
# host_identity_verified         -0.009257  0.016181    0.017537 -0.002013
# zipcode                        -0.139276  1.000000    0.330516 -0.634000
# accommodates                    0.393004 -0.015006   -0.047266 -0.026631
# bathrooms                       0.264883  0.053743    0.021594 -0.037161
# bedrooms                        0.291552  0.055956    0.008278 -0.062135
# beds                            0.300101  0.012683   -0.031875 -0.040826
# price                           0.757836 -0.181467   -0.122190  0.089869
# minimum_nights                 -0.131083 -0.014731   -0.017043 -0.001498
# maximum_nights                 -0.001603  0.008144    0.008855 -0.006191
# number_of_reviews               0.029765 -0.021943   -0.005017  0.004874
# review_scores_rating           -0.012882  0.041937   -0.014811 -0.027377
# review_scores_accuracy         -0.037056  0.060993    0.013531 -0.023356
# review_scores_cleanliness       0.003620  0.048335   -0.025411 -0.050662
# review_scores_checkin          -0.059721  0.053122    0.005734 -0.024750
# review_scores_communication    -0.062375  0.027851    0.002818  0.003124
# review_scores_location          0.096291 -0.182880   -0.182883  0.093958
# review_scores_value            -0.039742  0.081913    0.004245 -0.049165
# Price_daily                     1.000000 -0.139276   -0.094293  0.065438
# zip                            -0.139276  1.000000    0.330516 -0.634000
# population                     -0.094293  0.330516    1.000000  0.110317
# density                         0.065438 -0.634000    0.110317  1.000000

# %%
# Frequecy of Review Scores
freq_review_score = df_merge['review_scores_rating'].value_counts()
print(freq_review_score.head())
print('----')
print(freq_review_score.tail())

print('==============')
score_100 = df_merge[df_merge['review_scores_rating']==100.0]
print(score_100['borough'].value_counts())
# Out:
# 100.0    3585
# 96.0     1346
# 97.0     1317
# 98.0     1269
# 93.0     1213
# Name: review_scores_rating, dtype: int64
# ----
# 56.0    1
# 57.0    1
# 27.0    1
# 55.0    1
# 53.0    1
# Name: review_scores_rating, dtype: int64
# ==============
# Brooklyn         1621
# Manhattan        1449
# Queens            405
# Bronx              79
# Staten Island      31
# Name: borough, dtype: int64

# %%
scre_under75 = df_merge[df_merge['review_scores_rating']<75.0]
scre_under75.describe()
# Out:
#          Unnamed: 0            id  host_response_rate  host_is_superhost  \
# count    221.000000  2.210000e+02          221.000000         221.000000
# mean    8462.380090  1.364825e+07           88.380090           0.036199
# std     4931.375013  6.219837e+06           24.030669           0.187209
# min       46.000000  2.326900e+04            0.000000           0.000000
# 25%     3936.000000  8.368773e+06           90.000000           0.000000
# 50%     8873.000000  1.599208e+07          100.000000           0.000000
# 75%    12175.000000  1.889790e+07          100.000000           0.000000
# max    16756.000000  2.106293e+07          100.000000           1.000000
#
#        host_total_listings_count  host_has_profile_pic  \
# count                 221.000000            221.000000
# mean                    3.357466              0.990950
# std                     5.651532              0.094914
# min                     1.000000              0.000000
# 25%                     1.000000              1.000000
# 50%                     2.000000              1.000000
# 75%                     3.000000              1.000000
# max                    47.000000              1.000000
#
#        host_identity_verified       zipcode  accommodates   bathrooms  \
# count              221.000000    221.000000    221.000000  221.000000
# mean                 0.520362  10625.004525      3.194570    1.169683
# std                  0.500719    597.620787      2.199828    0.444087
# min                  0.000000  10001.000000      1.000000    0.000000
# 25%                  0.000000  10024.000000      2.000000    1.000000
# 50%                  1.000000  10463.000000      2.000000    1.000000
# 75%                  1.000000  11221.000000      4.000000    1.000000
# max                  1.000000  11432.000000     16.000000    4.000000
#
#          bedrooms        beds        price  minimum_nights  maximum_nights  \
# count  221.000000  221.000000   221.000000      221.000000      221.000000
# mean     1.312217    1.751131   187.606335        4.090498      640.733032
# std      0.784674    1.085676   678.097153        5.799761      533.418952
# min      0.000000    1.000000    23.000000        1.000000        1.000000
# 25%      1.000000    1.000000    60.000000        1.000000       30.000000
# 50%      1.000000    1.000000    90.000000        2.000000     1125.000000
# 75%      1.000000    2.000000   175.000000        4.000000     1125.000000
# max      5.000000    6.000000  9998.000000       30.000000     1125.000000
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count         221.000000            221.000000              221.000000
# mean            5.497738             61.850679                6.828054
# std             8.712908             13.033885                1.955721
# min             1.000000             20.000000                2.000000
# 25%             1.000000             60.000000                6.000000
# 50%             3.000000             64.000000                7.000000
# 75%             5.000000             71.000000                8.000000
# max            68.000000             74.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                 221.000000             221.000000
# mean                    6.502262               7.941176
# std                     1.992313               2.084832
# min                     2.000000               2.000000
# 25%                     6.000000               7.000000
# 50%                     7.000000               8.000000
# 75%                     8.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                   221.000000              221.000000
# mean                      7.669683                7.882353
# std                       2.045935                1.884073
# min                       2.000000                2.000000
# 25%                       7.000000                7.000000
# 50%                       8.000000                8.000000
# 75%                       9.000000                9.000000
# max                      10.000000               10.000000
#
#        review_scores_value  Price_daily           zip     population  \
# count           221.000000   221.000000    221.000000     221.000000
# mean              6.624434    95.913672  10625.004525   58769.855204
# std               1.851078   344.154557    597.620787   23322.825129
# min               2.000000     1.333333  10001.000000    3089.000000
# 25%               6.000000    20.000000  10024.000000   40366.000000
# 50%               7.000000    48.000000  10463.000000   57331.000000
# 75%               8.000000    86.666664  11221.000000   78895.000000
# max              10.000000  4999.000000  11432.000000  101572.000000
#
#              density
# count     221.000000
# mean    60491.846154
# std     30513.778509
# min      5519.000000
# 25%     35981.000000
# 50%     57033.000000
# 75%     81487.000000
# max    143683.000000

# %% [markdown]
# ### Scatter Plot

# %%
sns.regplot(data=df_merge, x='accommodates', y='Price_daily')

# %%
sns.regplot(data=df_merge, x='beds', y='Price_daily')

# %%
sns.regplot(data=df_merge, x='bathrooms', y='Price_daily')

# %%
scre_under75['borough'].value_counts()
# Out:
# Manhattan        102
# Brooklyn          78
# Queens            26
# Bronx             10
# Staten Island      5
# Name: borough, dtype: int64

# %% [markdown]
# ###  Highest Price Room

# %%
# Highest Daily Price
print(df_merge['Price_daily'].max())

# Highest Price
print(df_merge['price'].max())
# Out:
# 8000.0
# 10000.0

# %%
df_merge[df_merge['price']==10000.0]
# Out:
#      Unnamed: 0       id                              neighborhood_overview  \
# 352         352  7003697  Quiet, extremely safe, no parking space but I ...
#
#      host_response_rate  host_is_superhost  host_total_listings_count  \
# 352                 100                  0                        1.0
#
#      host_has_profile_pic  host_identity_verified  zipcode property_type  \
# 352                     1                       1    11103     Apartment
#
#         room_type  accommodates  bathrooms  bedrooms  beds    price  \
# 352  Private room             1        1.0       1.0   1.0  10000.0
#
#      minimum_nights  maximum_nights  number_of_reviews  review_scores_rating  \
# 352             100            1125                  2                 100.0
#
#      review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 352                    10.0                       10.0                   10.0
#
#      review_scores_communication  review_scores_location  review_scores_value  \
# 352                         10.0                    10.0                 10.0
#
#      Price_daily    zip borough  post_office      neighborhood  population  \
# 352        100.0  11103  Queens  Astoria, NY  Northwest Queens       38780
#
#      density
# 352    54537

# %%
df_merge[df_merge['Price_daily']==8000.0]
# Out:
#       Unnamed: 0       id neighborhood_overview  host_response_rate  \
# 4016        4016  2953058          Clinton HIll                 100
#
#       host_is_superhost  host_total_listings_count  host_has_profile_pic  \
# 4016                  1                       11.0                     1
#
#       host_identity_verified  zipcode property_type        room_type  \
# 4016                       1    11205         House  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds   price  minimum_nights  \
# 4016            16        6.0       5.0   5.0  8000.0               1
#
#       maximum_nights  number_of_reviews  review_scores_rating  \
# 4016            1125                  1                 100.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 4016                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# 4016                    6.0                          6.0
#
#       review_scores_location  review_scores_value  Price_daily    zip  \
# 4016                    10.0                 10.0       8000.0  11205
#
#        borough   post_office        neighborhood  population  density
# 4016  Brooklyn  Brooklyn, NY  Northwest Brooklyn       40366    42508

# %%
df_merge[df_merge['neighborhood']=='Northwest Brooklyn'].describe()
# Out:
#          Unnamed: 0            id  host_response_rate  host_is_superhost  \
# count   1141.000000  1.141000e+03         1141.000000        1141.000000
# mean    7921.166521  9.591209e+06           95.811569           0.263804
# std     3829.954733  6.600666e+06           13.082079           0.440887
# min     3879.000000  7.097000e+03            0.000000           0.000000
# 25%     5540.000000  3.601743e+06          100.000000           0.000000
# 50%     5825.000000  8.733620e+06          100.000000           0.000000
# 75%    13487.000000  1.579956e+07          100.000000           1.000000
# max    13772.000000  2.104338e+07          100.000000           1.000000
#
#        host_total_listings_count  host_has_profile_pic  \
# count                1141.000000                1141.0
# mean                    1.902717                   1.0
# std                     2.413449                   0.0
# min                     0.000000                   1.0
# 25%                     1.000000                   1.0
# 50%                     1.000000                   1.0
# 75%                     2.000000                   1.0
# max                    23.000000                   1.0
#
#        host_identity_verified       zipcode  accommodates    bathrooms  \
# count             1141.000000   1141.000000   1141.000000  1141.000000
# mean                 0.805434  11212.956179      3.285714     1.209465
# std                  0.396040      8.924331      2.155136     0.554042
# min                  0.000000  11201.000000      1.000000     0.000000
# 25%                  1.000000  11205.000000      2.000000     1.000000
# 50%                  1.000000  11215.000000      2.000000     1.000000
# 75%                  1.000000  11217.000000      4.000000     1.000000
# max                  1.000000  11231.000000     16.000000     6.000000
#
#           bedrooms         beds        price  minimum_nights  maximum_nights  \
# count  1141.000000  1141.000000  1141.000000     1141.000000     1141.000000
# mean      1.335670     1.843996   167.666959        3.852761      604.654689
# std       0.902452     1.386726   291.321899        5.828640      539.624151
# min       0.000000     1.000000    29.000000        1.000000        3.000000
# 25%       1.000000     1.000000    90.000000        2.000000       30.000000
# 50%       1.000000     1.000000   130.000000        2.000000     1125.000000
# 75%       2.000000     2.000000   178.000000        3.000000     1125.000000
# max      10.000000    13.000000  8000.000000       88.000000     3000.000000
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count        1141.000000           1141.000000             1141.000000
# mean           33.059597             95.127082                9.705521
# std            40.479061              5.562293                0.554926
# min             1.000000             50.000000                6.000000
# 25%             5.000000             93.000000                9.000000
# 50%            17.000000             97.000000               10.000000
# 75%            47.000000             99.000000               10.000000
# max           383.000000            100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                1141.000000            1141.000000
# mean                    9.483786               9.843120
# std                     0.747481               0.494637
# min                     4.000000               4.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  1141.000000             1141.000000
# mean                      9.868536                9.686240
# std                       0.419147                0.647312
# min                       6.000000                2.000000
# 25%                      10.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  Price_daily           zip    population  \
# count          1141.000000  1141.000000   1141.000000   1141.000000
# mean              9.567923    83.812273  11212.956179  46855.958808
# std               0.639343   279.932746      8.924331  11830.697842
# min               5.000000     1.079546  11201.000000  33336.000000
# 25%               9.000000    32.500000  11205.000000  35881.000000
# 50%              10.000000    55.000000  11215.000000  40366.000000
# 75%              10.000000    88.000000  11217.000000  63488.000000
# max              10.000000  8000.000000  11231.000000  63488.000000
#
#             density
# count   1141.000000
# mean   36504.815074
# std     8456.655591
# min    23441.000000
# 25%    29148.000000
# 50%    35981.000000
# 75%    42508.000000
# max    47796.000000

# %% [markdown]
# ID : 2953058
# Price: 8000
# Area: Brooklyn, NY
# Neighborhood：Northwest Brooklyn
# Minimum night: 1
# Price per night: $8000
#
#
# accommodates: 16
# bathrooms: 6
# beds: 5

# %% [markdown]
# ### Northwest Brooklyn Area
# Average Price per Nignt: $83
# Review Score Rating: 95.13
# Count: 1141
# Avg Northwest Brooklyn
#
# accommodates : 3.2
# bathrooms : 1.2
# beds : 1.8
#
#
# ID=2953058 Listing's 3 features are extremely higher than other listings. This is why the price is highest in NYC.

# %%
df_merge[df_merge['neighborhood']=='Northwest Brooklyn'].corr()
# Out:
#                              Unnamed: 0        id  host_response_rate  \
# Unnamed: 0                     1.000000 -0.040246            0.023026
# id                            -0.040246  1.000000            0.022688
# host_response_rate             0.023026  0.022688            1.000000
# host_is_superhost              0.057475 -0.162044            0.148394
# host_total_listings_count     -0.105235 -0.094581            0.072044
# host_has_profile_pic                NaN       NaN                 NaN
# host_identity_verified        -0.024979 -0.245637            0.063689
# zipcode                        0.402975 -0.012754            0.016504
# accommodates                   0.042196 -0.064510            0.059315
# bathrooms                     -0.043867 -0.045556            0.034557
# bedrooms                       0.057532 -0.071816            0.043107
# beds                           0.067693 -0.068839            0.064381
# price                         -0.041472 -0.077967            0.031035
# minimum_nights                -0.000796 -0.124121           -0.001549
# maximum_nights                 0.022256  0.051581            0.009312
# number_of_reviews              0.050414 -0.429504            0.117940
# review_scores_rating           0.065881  0.109613            0.074274
# review_scores_accuracy         0.061687  0.092255            0.039233
# review_scores_cleanliness      0.094437  0.123319            0.116798
# review_scores_checkin          0.050147 -0.014565            0.066597
# review_scores_communication    0.050360  0.010904            0.075146
# review_scores_location         0.148642  0.007749            0.098153
# review_scores_value            0.077272  0.128431            0.081396
# Price_daily                   -0.052903 -0.043136            0.020932
# zip                            0.402975 -0.012754            0.016504
# population                     0.794810 -0.029841            0.014090
# density                       -0.712079 -0.034349           -0.032108
#
#                              host_is_superhost  host_total_listings_count  \
# Unnamed: 0                            0.057475                  -0.105235
# id                                   -0.162044                  -0.094581
# host_response_rate                    0.148394                   0.072044
# host_is_superhost                     1.000000                   0.085144
# host_total_listings_count             0.085144                   1.000000
# host_has_profile_pic                       NaN                        NaN
# host_identity_verified                0.103311                   0.071953
# zipcode                               0.016317                  -0.030743
# accommodates                          0.106167                   0.091022
# bathrooms                            -0.003767                   0.209761
# bedrooms                              0.037398                   0.043601
# beds                                  0.111849                   0.036087
# price                                 0.102603                   0.180664
# minimum_nights                       -0.077036                   0.139348
# maximum_nights                       -0.046892                   0.043924
# number_of_reviews                     0.360136                   0.054948
# review_scores_rating                  0.204154                  -0.108398
# review_scores_accuracy                0.217409                  -0.138649
# review_scores_cleanliness             0.269849                  -0.056064
# review_scores_checkin                 0.121559                  -0.167104
# review_scores_communication           0.121378                  -0.174809
# review_scores_location                0.124304                  -0.096480
# review_scores_value                   0.205561                  -0.115950
# Price_daily                           0.089402                   0.196713
# zip                                   0.016317                  -0.030743
# population                            0.049894                  -0.097541
# density                               0.006233                   0.122745
#
#                              host_has_profile_pic  host_identity_verified  \
# Unnamed: 0                                    NaN               -0.024979
# id                                            NaN               -0.245637
# host_response_rate                            NaN                0.063689
# host_is_superhost                             NaN                0.103311
# host_total_listings_count                     NaN                0.071953
# host_has_profile_pic                          NaN                     NaN
# host_identity_verified                        NaN                1.000000
# zipcode                                       NaN               -0.083820
# accommodates                                  NaN               -0.014976
# bathrooms                                     NaN                0.019994
# bedrooms                                      NaN                0.023362
# beds                                          NaN                0.008573
# price                                         NaN                0.016780
# minimum_nights                                NaN                0.056360
# maximum_nights                                NaN                0.025363
# number_of_reviews                             NaN                0.122634
# review_scores_rating                          NaN               -0.001907
# review_scores_accuracy                        NaN                0.030437
# review_scores_cleanliness                     NaN               -0.007703
# review_scores_checkin                         NaN                0.036596
# review_scores_communication                   NaN                0.046582
# review_scores_location                        NaN               -0.043301
# review_scores_value                           NaN                0.014131
# Price_daily                                   NaN                0.011368
# zip                                           NaN               -0.083820
# population                                    NaN                0.024741
# density                                       NaN                0.083726
#
#                               zipcode  accommodates  bathrooms  bedrooms  \
# Unnamed: 0                   0.402975      0.042196  -0.043867  0.057532
# id                          -0.012754     -0.064510  -0.045556 -0.071816
# host_response_rate           0.016504      0.059315   0.034557  0.043107
# host_is_superhost            0.016317      0.106167  -0.003767  0.037398
# host_total_listings_count   -0.030743      0.091022   0.209761  0.043601
# host_has_profile_pic              NaN           NaN        NaN       NaN
# host_identity_verified      -0.083820     -0.014976   0.019994  0.023362
# zipcode                      1.000000      0.103635   0.028115  0.115102
# accommodates                 0.103635      1.000000   0.564732  0.761580
# bathrooms                    0.028115      0.564732   1.000000  0.561889
# bedrooms                     0.115102      0.761580   0.561889  1.000000
# beds                         0.112856      0.873457   0.537507  0.764549
# price                       -0.002668      0.502290   0.520179  0.429726
# minimum_nights              -0.039754     -0.043016   0.075430  0.007403
# maximum_nights               0.065681      0.095596   0.074484  0.071443
# number_of_reviews           -0.007030      0.036969  -0.070589 -0.074555
# review_scores_rating         0.030401     -0.004788  -0.012630  0.033959
# review_scores_accuracy       0.021127     -0.002200  -0.031725 -0.010886
# review_scores_cleanliness    0.032636     -0.006379  -0.037332 -0.006879
# review_scores_checkin        0.051697     -0.058307  -0.105646 -0.039135
# review_scores_communication  0.006432     -0.092391  -0.158951 -0.054843
# review_scores_location       0.103911      0.000180  -0.015926 -0.007253
# review_scores_value          0.036958     -0.032559  -0.010484 -0.006863
# Price_daily                 -0.016987      0.360817   0.413686  0.272084
# zip                          1.000000      0.103635   0.028115  0.115102
# population                  -0.231799     -0.022828  -0.067275 -0.015757
# density                     -0.439382     -0.068221   0.006170 -0.062138
#
#                                  beds     price  minimum_nights  \
# Unnamed: 0                   0.067693 -0.041472       -0.000796
# id                          -0.068839 -0.077967       -0.124121
# host_response_rate           0.064381  0.031035       -0.001549
# host_is_superhost            0.111849  0.102603       -0.077036
# host_total_listings_count    0.036087  0.180664        0.139348
# host_has_profile_pic              NaN       NaN             NaN
# host_identity_verified       0.008573  0.016780        0.056360
# zipcode                      0.112856 -0.002668       -0.039754
# accommodates                 0.873457  0.502290       -0.043016
# bathrooms                    0.537507  0.520179        0.075430
# bedrooms                     0.764549  0.429726        0.007403
# beds                         1.000000  0.348830       -0.030410
# price                        0.348830  1.000000       -0.011994
# minimum_nights              -0.030410 -0.011994        1.000000
# maximum_nights               0.064432  0.051618        0.013057
# number_of_reviews            0.032170 -0.041311       -0.107391
# review_scores_rating         0.001890  0.067031       -0.044147
# review_scores_accuracy      -0.010735  0.041928       -0.060335
# review_scores_cleanliness   -0.000750  0.040431       -0.037393
# review_scores_checkin       -0.026759 -0.184904       -0.094124
# review_scores_communication -0.071535 -0.200845       -0.111697
# review_scores_location      -0.009625  0.051846       -0.032017
# review_scores_value         -0.015741  0.023882       -0.013556
# Price_daily                  0.198946  0.957306       -0.095229
# zip                          0.112856 -0.002668       -0.039754
# population                  -0.002082 -0.041636        0.024946
# density                     -0.067228  0.005611        0.003036
#
#                              maximum_nights  number_of_reviews  \
# Unnamed: 0                         0.022256           0.050414
# id                                 0.051581          -0.429504
# host_response_rate                 0.009312           0.117940
# host_is_superhost                 -0.046892           0.360136
# host_total_listings_count          0.043924           0.054948
# host_has_profile_pic                    NaN                NaN
# host_identity_verified             0.025363           0.122634
# zipcode                            0.065681          -0.007030
# accommodates                       0.095596           0.036969
# bathrooms                          0.074484          -0.070589
# bedrooms                           0.071443          -0.074555
# beds                               0.064432           0.032170
# price                              0.051618          -0.041311
# minimum_nights                     0.013057          -0.107391
# maximum_nights                     1.000000          -0.051198
# number_of_reviews                 -0.051198           1.000000
# review_scores_rating              -0.062611          -0.020363
# review_scores_accuracy            -0.074499           0.040418
# review_scores_cleanliness         -0.004494           0.084686
# review_scores_checkin             -0.047057           0.096150
# review_scores_communication       -0.086031           0.047096
# review_scores_location            -0.027399           0.026391
# review_scores_value               -0.055088          -0.000631
# Price_daily                        0.057865          -0.014570
# zip                                0.065681          -0.007030
# population                        -0.019064           0.055826
# density                           -0.039918           0.017941
#
#                              review_scores_rating  review_scores_accuracy  \
# Unnamed: 0                               0.065881                0.061687
# id                                       0.109613                0.092255
# host_response_rate                       0.074274                0.039233
# host_is_superhost                        0.204154                0.217409
# host_total_listings_count               -0.108398               -0.138649
# host_has_profile_pic                          NaN                     NaN
# host_identity_verified                  -0.001907                0.030437
# zipcode                                  0.030401                0.021127
# accommodates                            -0.004788               -0.002200
# bathrooms                               -0.012630               -0.031725
# bedrooms                                 0.033959               -0.010886
# beds                                     0.001890               -0.010735
# price                                    0.067031                0.041928
# minimum_nights                          -0.044147               -0.060335
# maximum_nights                          -0.062611               -0.074499
# number_of_reviews                       -0.020363                0.040418
# review_scores_rating                     1.000000                0.649853
# review_scores_accuracy                   0.649853                1.000000
# review_scores_cleanliness                0.634174                0.540430
# review_scores_checkin                    0.496333                0.448327
# review_scores_communication              0.510968                0.459453
# review_scores_location                   0.497610                0.418991
# review_scores_value                      0.711789                0.639922
# Price_daily                              0.040499                0.029510
# zip                                      0.030401                0.021127
# population                               0.051729                0.054432
# density                                 -0.029538               -0.039782
#
#                              review_scores_cleanliness  review_scores_checkin  \
# Unnamed: 0                                    0.094437               0.050147
# id                                            0.123319              -0.014565
# host_response_rate                            0.116798               0.066597
# host_is_superhost                             0.269849               0.121559
# host_total_listings_count                    -0.056064              -0.167104
# host_has_profile_pic                               NaN                    NaN
# host_identity_verified                       -0.007703               0.036596
# zipcode                                       0.032636               0.051697
# accommodates                                 -0.006379              -0.058307
# bathrooms                                    -0.037332              -0.105646
# bedrooms                                     -0.006879              -0.039135
# beds                                         -0.000750              -0.026759
# price                                         0.040431              -0.184904
# minimum_nights                               -0.037393              -0.094124
# maximum_nights                               -0.004494              -0.047057
# number_of_reviews                             0.084686               0.096150
# review_scores_rating                          0.634174               0.496333
# review_scores_accuracy                        0.540430               0.448327
# review_scores_cleanliness                     1.000000               0.359668
# review_scores_checkin                         0.359668               1.000000
# review_scores_communication                   0.387963               0.598550
# review_scores_location                        0.313992               0.385844
# review_scores_value                           0.525891               0.434538
# Price_daily                                   0.012482              -0.201154
# zip                                           0.032636               0.051697
# population                                    0.081174               0.019091
# density                                      -0.069959              -0.034908
#
#                              review_scores_communication  \
# Unnamed: 0                                      0.050360
# id                                              0.010904
# host_response_rate                              0.075146
# host_is_superhost                               0.121378
# host_total_listings_count                      -0.174809
# host_has_profile_pic                                 NaN
# host_identity_verified                          0.046582
# zipcode                                         0.006432
# accommodates                                   -0.092391
# bathrooms                                      -0.158951
# bedrooms                                       -0.054843
# beds                                           -0.071535
# price                                          -0.200845
# minimum_nights                                 -0.111697
# maximum_nights                                 -0.086031
# number_of_reviews                               0.047096
# review_scores_rating                            0.510968
# review_scores_accuracy                          0.459453
# review_scores_cleanliness                       0.387963
# review_scores_checkin                           0.598550
# review_scores_communication                     1.000000
# review_scores_location                          0.313401
# review_scores_value                             0.422881
# Price_daily                                    -0.217594
# zip                                             0.006432
# population                                      0.049900
# density                                        -0.021833
#
#                              review_scores_location  review_scores_value  \
# Unnamed: 0                                 0.148642             0.077272
# id                                         0.007749             0.128431
# host_response_rate                         0.098153             0.081396
# host_is_superhost                          0.124304             0.205561
# host_total_listings_count                 -0.096480            -0.115950
# host_has_profile_pic                            NaN                  NaN
# host_identity_verified                    -0.043301             0.014131
# zipcode                                    0.103911             0.036958
# accommodates                               0.000180            -0.032559
# bathrooms                                 -0.015926            -0.010484
# bedrooms                                  -0.007253            -0.006863
# beds                                      -0.009625            -0.015741
# price                                      0.051846             0.023882
# minimum_nights                            -0.032017            -0.013556
# maximum_nights                            -0.027399            -0.055088
# number_of_reviews                          0.026391            -0.000631
# review_scores_rating                       0.497610             0.711789
# review_scores_accuracy                     0.418991             0.639922
# review_scores_cleanliness                  0.313992             0.525891
# review_scores_checkin                      0.385844             0.434538
# review_scores_communication                0.313401             0.422881
# review_scores_location                     1.000000             0.471215
# review_scores_value                        0.471215             1.000000
# Price_daily                                0.035895             0.019081
# zip                                        0.103911             0.036958
# population                                 0.093978             0.059159
# density                                   -0.062177            -0.046995
#
#                              Price_daily       zip  population   density
# Unnamed: 0                     -0.052903  0.402975    0.794810 -0.712079
# id                             -0.043136 -0.012754   -0.029841 -0.034349
# host_response_rate              0.020932  0.016504    0.014090 -0.032108
# host_is_superhost               0.089402  0.016317    0.049894  0.006233
# host_total_listings_count       0.196713 -0.030743   -0.097541  0.122745
# host_has_profile_pic                 NaN       NaN         NaN       NaN
# host_identity_verified          0.011368 -0.083820    0.024741  0.083726
# zipcode                        -0.016987  1.000000   -0.231799 -0.439382
# accommodates                    0.360817  0.103635   -0.022828 -0.068221
# bathrooms                       0.413686  0.028115   -0.067275  0.006170
# bedrooms                        0.272084  0.115102   -0.015757 -0.062138
# beds                            0.198946  0.112856   -0.002082 -0.067228
# price                           0.957306 -0.002668   -0.041636  0.005611
# minimum_nights                 -0.095229 -0.039754    0.024946  0.003036
# maximum_nights                  0.057865  0.065681   -0.019064 -0.039918
# number_of_reviews              -0.014570 -0.007030    0.055826  0.017941
# review_scores_rating            0.040499  0.030401    0.051729 -0.029538
# review_scores_accuracy          0.029510  0.021127    0.054432 -0.039782
# review_scores_cleanliness       0.012482  0.032636    0.081174 -0.069959
# review_scores_checkin          -0.201154  0.051697    0.019091 -0.034908
# review_scores_communication    -0.217594  0.006432    0.049900 -0.021833
# review_scores_location          0.035895  0.103911    0.093978 -0.062177
# review_scores_value             0.019081  0.036958    0.059159 -0.046995
# Price_daily                     1.000000 -0.016987   -0.045713  0.023456
# zip                            -0.016987  1.000000   -0.231799 -0.439382
# population                     -0.045713 -0.231799    1.000000 -0.497214
# density                         0.023456 -0.439382   -0.497214  1.000000

# %% [markdown]
# ### Highest accommodates/bathrooms/beds

# %%
# Price for Highest accommodates
df_merge[df_merge['accommodates']==16]['Price_daily'].describe()
# Out:
# count      53.000000
# mean      700.488994
# std      1242.195635
# min        70.000000
# 25%       159.000000
# 50%       335.000000
# 75%       675.000000
# max      8000.000000
# Name: Price_daily, dtype: float64

# %%
# Price for Highest bathrooms
df_merge[df_merge['bathrooms']==15.5]['Price_daily'].describe()
# Out:
# count      1.0
# mean     742.5
# std        NaN
# min      742.5
# 25%      742.5
# 50%      742.5
# 75%      742.5
# max      742.5
# Name: Price_daily, dtype: float64

# %%
# Price for Highest bathrooms
df_merge[df_merge['beds']==40.0]['Price_daily'].describe()
# Out:
# count      1.0
# mean     742.5
# std        NaN
# min      742.5
# 25%      742.5
# 50%      742.5
# 75%      742.5
# max      742.5
# Name: Price_daily, dtype: float64

# %% [markdown]
# ### Super Host

# %%
# Create Super host datasets
super_host = df_merge[df_merge['host_is_superhost']==1.0]

# %%
# Count of Super Host
super_host['borough'].value_counts()
# Out:
# Brooklyn         1566
# Manhattan        1275
# Queens            415
# Bronx             108
# Staten Island      38
# Name: borough, dtype: int64

# %%
# Price Details
super_host['Price_daily'].describe()
# Out:
# count    3402.000000
# mean       79.964884
# std       186.682994
# min         0.000000
# 25%        31.666666
# 50%        53.000000
# 75%        89.000000
# max      8000.000000
# Name: Price_daily, dtype: float64

# %%
# Score Details
super_host['review_scores_rating'].describe()
# Out:
# count    3402.000000
# mean       96.774838
# std         3.116833
# min        60.000000
# 25%        96.000000
# 50%        97.000000
# 75%        99.000000
# max       100.000000
# Name: review_scores_rating, dtype: float64

# %% [markdown]
# ### Score 100 Listing

# %%
# Count of Super Host with Score100 listings
score_100['host_is_superhost'].value_counts()
# Out:
# 0    3143
# 1     442
# Name: host_is_superhost, dtype: int64

# %%
score_100.describe()
# Out:
#          Unnamed: 0            id  host_response_rate  host_is_superhost  \
# count   3585.000000  3.585000e+03         3585.000000        3585.000000
# mean    8248.203626  1.459968e+07           94.760669           0.123291
# std     4868.669569  5.942164e+06           14.985863           0.328817
# min        2.000000  7.036000e+03            0.000000           0.000000
# 25%     4196.000000  1.019256e+07          100.000000           0.000000
# 50%     7962.000000  1.652772e+07          100.000000           0.000000
# 75%    12681.000000  1.947341e+07          100.000000           0.000000
# max    16784.000000  2.115454e+07          100.000000           1.000000
#
#        host_total_listings_count  host_has_profile_pic  \
# count                3585.000000           3585.000000
# mean                    3.004184              0.998884
# std                    28.858940              0.033389
# min                     0.000000              0.000000
# 25%                     1.000000              1.000000
# 50%                     1.000000              1.000000
# 75%                     2.000000              1.000000
# max                   979.000000              1.000000
#
#        host_identity_verified       zipcode  accommodates    bathrooms  \
# count             3585.000000   3585.000000   3585.000000  3585.000000
# mean                 0.658577  10719.308787      2.825941     1.159414
# std                  0.474253    592.501347      1.880898     0.513257
# min                  0.000000  10001.000000      1.000000     0.000000
# 25%                  0.000000  10026.000000      2.000000     1.000000
# 50%                  1.000000  11204.000000      2.000000     1.000000
# 75%                  1.000000  11221.000000      4.000000     1.000000
# max                  1.000000  11693.000000     16.000000    15.500000
#
#           bedrooms         beds         price  minimum_nights  maximum_nights  \
# count  3585.000000  3585.000000   3585.000000     3585.000000    3.585000e+03
# mean      1.200558     1.574616    154.017015        4.356206    4.306866e+04
# std       0.779337     1.217237    271.172432        7.884633    2.538619e+06
# min       0.000000     1.000000      0.000000        1.000000    1.000000e+00
# 25%       1.000000     1.000000     70.000000        2.000000    2.700000e+01
# 50%       1.000000     1.000000    110.000000        2.000000    1.125000e+03
# 75%       1.000000     2.000000    179.000000        4.000000    1.125000e+03
# max      14.000000    40.000000  10000.000000      160.000000    1.520000e+08
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count        3585.000000                3585.0             3585.000000
# mean            5.781590                 100.0                9.918828
# std             9.321693                   0.0                0.382141
# min             1.000000                 100.0                2.000000
# 25%             2.000000                 100.0               10.000000
# 50%             3.000000                 100.0               10.000000
# 75%             6.000000                 100.0               10.000000
# max           264.000000                 100.0               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                3585.000000            3585.000000
# mean                    9.802232               9.936123
# std                     0.538367               0.317975
# min                     4.000000               6.000000
# 25%                    10.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  3585.000000             3585.000000
# mean                      9.955927                9.737796
# std                       0.288854                0.600300
# min                       2.000000                6.000000
# 25%                      10.000000               10.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  Price_daily           zip     population  \
# count          3585.000000  3585.000000   3585.000000    3585.000000
# mean              9.840725    76.674885  10719.308787   56458.600279
# std               0.489298   193.356456    592.501347   22965.038627
# min               2.000000     0.000000  10001.000000    3011.000000
# 25%              10.000000    25.000000  10026.000000   36934.000000
# 50%              10.000000    49.000000  11204.000000   55909.000000
# 75%              10.000000    85.000000  11221.000000   78895.000000
# max              10.000000  8000.000000  11693.000000  109931.000000
#
#              density
# count    3585.000000
# mean    59950.167922
# std     28958.917612
# min      1295.000000
# 25%     39209.000000
# 50%     56119.000000
# 75%     78775.000000
# max    143683.000000

# %%
score_100['Price_daily'].describe()
# Out:
# count    3585.000000
# mean       76.674885
# std       193.356456
# min         0.000000
# 25%        25.000000
# 50%        49.000000
# 75%        85.000000
# max      8000.000000
# Name: Price_daily, dtype: float64
