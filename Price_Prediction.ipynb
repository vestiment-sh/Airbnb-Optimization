# %%
# import modules
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# import datasets
df = pd.read_csv('data_predict.csv')

# %%
df.head()
# Out:
#          id  host_response_rate  host_is_superhost  host_total_listings_count  \
# 0   6627449                 100              False                          1
# 1   5557381                 100               True                          1
# 2  19609887                 100              False                          1
# 3   7949480                 100               True                          1
# 4   9147025                 100               True                          1
#
#    host_has_profile_pic  host_identity_verified  zipcode property_type  \
# 0                  True                    True    10464     Apartment
# 1                  True                    True    10464         House
# 2                  True                   False    10464     Apartment
# 3                  True                    True    10464         House
# 4                  True                   False    10464         House
#
#          room_type  accommodates  bathrooms  bedrooms  beds price  \
# 0  Entire home/apt             3        1.0         1     1   125
# 1     Private room             4        1.0         1     1    69
# 2  Entire home/apt             7        1.0         2     5   150
# 3     Private room             2        1.0         1     1   101
# 4  Entire home/apt             2        1.0         0     1   125
#
#    minimum_nights  maximum_nights  number_of_reviews  review_scores_rating  \
# 0               3              21                 21                    95
# 1               3            1125                 94                    97
# 2               2            1125                  3                   100
# 3               1               7                 31                   100
# 4               2              28                 60                    97
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                      10                         10                     10
# 1                      10                         10                     10
# 2                      10                         10                     10
# 3                      10                         10                     10
# 4                      10                         10                     10
#
#    review_scores_communication  review_scores_location  review_scores_value
# 0                           10                      10                   10
# 1                           10                      10                   10
# 2                           10                      10                   10
# 3                           10                      10                   10
# 4                           10                      10                   10

# %%
# Cleaning Data
df['price'] = df['price'].str.strip('$')
df['price'] = df['price'].str.replace(',','')
df['price'] = df['price'].astype(np.float32)

# Convert the boolean to int
arr_mapping = {True:1, False:0}
df['host_is_superhost'] = df['host_is_superhost'].map(arr_mapping)
df['host_has_profile_pic'] = df['host_has_profile_pic'].map(arr_mapping)
df['host_identity_verified'] = df['host_identity_verified'].map(arr_mapping)

# Create New Column
df['Price_daily'] = df['price']/df['minimum_nights']
df = df.drop('price', axis=1)

# %%
# Create X and Y to predict Listing Price 
y = np.array(df['Price_daily'])

df_x = df.drop(['Price_daily','id','zipcode'], axis=1)
df_x_dummy = pd.get_dummies(df_x)
# create dummy variables by categorical data
x = np.array(df_x_dummy)

# %%
# Fit the model
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict the price
Y_pred = model.predict(x)

# %%
# Create the column about Predicted Price
df['predicted_price'] = Y_pred

# %%
# Calculate the diff
df['diif_price'] = df['Price_daily'] - df['predicted_price']

# %%
df.head()
# Out:
#          id  host_response_rate  host_is_superhost  host_total_listings_count  \
# 0   6627449                 100                  0                          1
# 1   5557381                 100                  1                          1
# 2  19609887                 100                  0                          1
# 3   7949480                 100                  1                          1
# 4   9147025                 100                  1                          1
#
#    host_has_profile_pic  host_identity_verified  zipcode property_type  \
# 0                     1                       1    10464     Apartment
# 1                     1                       1    10464         House
# 2                     1                       0    10464     Apartment
# 3                     1                       1    10464         House
# 4                     1                       0    10464         House
#
#          room_type  accommodates  bathrooms  bedrooms  beds  minimum_nights  \
# 0  Entire home/apt             3        1.0         1     1               3
# 1     Private room             4        1.0         1     1               3
# 2  Entire home/apt             7        1.0         2     5               2
# 3     Private room             2        1.0         1     1               1
# 4  Entire home/apt             2        1.0         0     1               2
#
#    maximum_nights  number_of_reviews  review_scores_rating  \
# 0              21                 21                    95
# 1            1125                 94                    97
# 2            1125                  3                   100
# 3               7                 31                   100
# 4              28                 60                    97
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                      10                         10                     10
# 1                      10                         10                     10
# 2                      10                         10                     10
# 3                      10                         10                     10
# 4                      10                         10                     10
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                           10                      10                   10
# 1                           10                      10                   10
# 2                           10                      10                   10
# 3                           10                      10                   10
# 4                           10                      10                   10
#
#    Price_daily  predicted_price  diif_price
# 0    41.666667        80.203275  -38.536608
# 1    23.000000       103.920700  -80.920700
# 2    75.000000       115.790172  -40.790172
# 3   101.000000        60.785434   40.214566
# 4    62.500000        53.505134    8.994866

# %%
# Show the Negative largest difference between actial price and predicted price
# This is the listings that we can propose that they can increase their price
df.sort_values('diif_price').head(5)
# Out:
#             id  host_response_rate  host_is_superhost  \
# 6712   7089310                 100                  0
# 4948  11708688                 100                  0
# 2455    512209                 100                  1
# 6917    867220                 100                  0
# 7378  16923912                 100                  0
#
#       host_total_listings_count  host_has_profile_pic  host_identity_verified  \
# 6712                          1                     1                       1
# 4948                          1                     1                       0
# 2455                          1                     1                       1
# 6917                          1                     1                       1
# 7378                          2                     1                       0
#
#       zipcode property_type        room_type  accommodates  bathrooms  \
# 6712    11432         House  Entire home/apt            16        5.5
# 4948    10456     Apartment  Entire home/apt            15        1.0
# 2455    11201         House  Entire home/apt            16        5.5
# 6917    11226         House  Entire home/apt            16        4.0
# 7378    11375         House  Entire home/apt            10        4.5
#
#       bedrooms  beds  minimum_nights  maximum_nights  number_of_reviews  \
# 6712         5     5               3              28                 15
# 4948         2     3               1            1125                  6
# 2455         5    12               5              99                 47
# 6917         5     5               3            1125                 13
# 7378         6     8               5              57                  2
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 6712                    80                       9                          8
# 4948                    95                      10                         10
# 2455                    99                      10                         10
# 6917                    88                       9                         10
# 7378                   100                      10                         10
#
#       review_scores_checkin  review_scores_communication  \
# 6712                      9                            9
# 4948                      8                           10
# 2455                     10                           10
# 6917                      9                            9
# 7378                     10                           10
#
#       review_scores_location  review_scores_value  Price_daily  \
# 6712                       9                    9   132.666667
# 4948                      10                   10    75.000000
# 2455                      10                   10   160.000000
# 6917                       9                    9   246.666667
# 7378                      10                    9    80.000000
#
#       predicted_price  diif_price
# 6712       591.340913 -458.674247
# 4948       394.741657 -319.741657
# 2455       455.508014 -295.508014
# 6917       530.750826 -284.084159
# 7378       354.688546 -274.688546

# %%
# Show the positive largest difference between actial price and predicted price
df.sort_values('diif_price').tail(10)
# Out:
#             id  host_response_rate  host_is_superhost  \
# 7123   3585309                 100                  0
# 7221  18854380                 100                  0
# 2378  12591059                  50                  0
# 7054   3181834                 100                  0
# 3857  19178296                 100                  0
# 3586   1056256                 100                  0
# 3814  12469563                 100                  0
# 5638   2939700                   0                  0
# 4141   2952861                 100                  1
# 4143   2953058                 100                  1
#
#       host_total_listings_count  host_has_profile_pic  host_identity_verified  \
# 7123                          2                     1                       0
# 7221                          1                     1                       0
# 2378                          1                     1                       0
# 7054                          1                     1                       1
# 3857                          1                     1                       0
# 3586                         17                     1                       1
# 3814                          2                     1                       1
# 5638                          1                     1                       0
# 4141                         11                     1                       1
# 4143                         11                     1                       1
#
#       zipcode property_type        room_type  accommodates  bathrooms  \
# 7123    11358         House  Entire home/apt             9        3.0
# 7221    11354   Condominium  Entire home/apt             2        1.0
# 2378    11225     Apartment  Entire home/apt             4        1.0
# 7054    10011     Apartment  Entire home/apt            10        2.0
# 3857    10001     Apartment  Entire home/apt            10        1.5
# 3586    11231         House  Entire home/apt            12        2.5
# 3814    10001     Apartment  Entire home/apt            10        2.0
# 5638    10128     Apartment  Entire home/apt             8        3.5
# 4141    11205         House  Entire home/apt            16        6.0
# 4143    11205         House  Entire home/apt            16        6.0
#
#       bedrooms  beds  minimum_nights  maximum_nights  number_of_reviews  \
# 7123         4     5               1            1125                  9
# 7221         0     1             365             365                  6
# 2378         2     2               1            1125                  4
# 7054         4     5               1            1125                 15
# 3857         4     5               1            1125                  3
# 3586         5     5               1             365                 46
# 3814         4     4               1            1125                 11
# 5638         5     5               1            1125                  1
# 4141         5     5               1            1125                  3
# 4143         5     5               1            1125                  1
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 7123                   100                      10                         10
# 7221                    88                       8                          9
# 2378                    80                       9                          7
# 7054                    92                       9                         10
# 3857                    93                       9                          9
# 3586                    94                       9                          9
# 3814                    94                       9                          9
# 5638                   100                      10                         10
# 4141                   100                      10                          9
# 4143                   100                      10                         10
#
#       review_scores_checkin  review_scores_communication  \
# 7123                     10                           10
# 7221                      9                            8
# 2378                      9                           10
# 7054                      9                            9
# 3857                      9                            9
# 3586                     10                           10
# 3814                      9                            9
# 5638                     10                           10
# 4141                      9                           10
# 4143                      6                            6
#
#       review_scores_location  review_scores_value  Price_daily  \
# 7123                      10                   10   950.000000
# 7221                       9                    8     0.452055
# 2378                      10                    8   800.000000
# 7054                      10                    9   990.000000
# 3857                       9                    9   990.000000
# 3586                      10                    9  1395.000000
# 3814                       9                    9  1500.000000
# 5638                      10                   10  2500.000000
# 4141                      10                   10  4500.000000
# 4143                      10                   10  8000.000000
#
#       predicted_price   diif_price
# 7123       292.877986   657.122014
# 7221      -672.099410   672.551464
# 2378       114.606462   685.393538
# 7054       295.041393   694.958607
# 3857       248.739828   741.260172
# 3586       352.723361  1042.276639
# 3814       297.732107  1202.267893
# 5638       322.629584  2177.370416
# 4141       659.818948  3840.181052
# 4143       764.232931  7235.767069

# %%
# Confrim the correlation
pd.DataFrame(df.corr()['Price_daily']).sort_values('Price_daily', ascending=False)
# Out:
#                              Price_daily
# Price_daily                     1.000000
# diif_price                      0.891564
# predicted_price                 0.452894
# accommodates                    0.367932
# bedrooms                        0.288813
# beds                            0.267686
# bathrooms                       0.259970
# review_scores_location          0.083667
# host_is_superhost               0.023434
# review_scores_cleanliness       0.018885
# number_of_reviews               0.017249
# review_scores_rating            0.009161
# host_has_profile_pic            0.003600
# host_total_listings_count      -0.001251
# host_response_rate             -0.003722
# maximum_nights                 -0.004380
# host_identity_verified         -0.006906
# review_scores_accuracy         -0.006993
# id                             -0.016068
# review_scores_value            -0.017508
# review_scores_communication    -0.062392
# review_scores_checkin          -0.063431
# minimum_nights                 -0.122721
# zipcode                        -0.125526
